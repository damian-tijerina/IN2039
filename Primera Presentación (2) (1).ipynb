# %%
#Damián Guadalupe Tijerina Peña 
#A00827880

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df=pd.read_csv('datasets/EPL_20_21.csv')
df.head()
# Out:
#             Name     Club Nationality Position  Age  Matches  Starts  Mins  \
# 0    Mason Mount  Chelsea         ENG    MF,FW   21       36      32  2890
# 1  Edouard Mendy  Chelsea         SEN       GK   28       31      31  2745
# 2    Timo Werner  Chelsea         GER       FW   24       35      29  2602
# 3   Ben Chilwell  Chelsea         ENG       DF   23       27      27  2286
# 4    Reece James  Chelsea         ENG       DF   20       32      25  2373
#
#    Goals  Assists  Passes_Attempted  Perc_Passes_Completed  Penalty_Goals  \
# 0      6        5              1881                   82.3              1
# 1      0        0              1007                   84.6              0
# 2      6        8               826                   77.2              0
# 3      3        5              1806                   78.6              0
# 4      1        2              1987                   85.0              0
#
#    Penalty_Attempted    xG    xA  Yellow_Cards  Red_Cards
# 0                  1  0.21  0.24             2          0
# 1                  0  0.00  0.00             2          0
# 2                  0  0.41  0.21             2          0
# 3                  0  0.10  0.11             3          0
# 4                  0  0.06  0.12             3          0

# %%
df.columns
# Out:
# Index(['Name', 'Club', 'Nationality', 'Position', 'Age', 'Matches', 'Starts',
#        'Mins', 'Goals', 'Assists', 'Passes_Attempted', 'Perc_Passes_Completed',
#        'Penalty_Goals', 'Penalty_Attempted', 'xG', 'xA', 'Yellow_Cards',
#        'Red_Cards'],
#       dtype='object')

# %%
pd.pivot_table(df,
              index='Club',
              values='Goals',
              columns='Position',
              aggfunc='sum',
              fill_value=0,
              margins=True)
# Out:
# Position                  DF  DF,FW  DF,MF   FW  FW,DF  FW,MF  GK   MF  MF,DF  \
# Club
# Arsenal                    5      0      0   37      5      1   0    2      1
# Aston Villa                5      0      0   33      0      7   0    7      0
# Brighton                  11      0      0    8      0     13   0    1      4
# Burnley                    5      0      0   18      0      1   0    8      0
# Chelsea                   15      0      0   16      2      6   0    7      0
# Crystal Palace             4      0      0   24      0      1   0    9      0
# Everton                    6      0      0   23      1      6   0    8      0
# Fulham                     3      1      0    3      0     10   0    2      5
# Leeds United               4      0      9   17      0      0   0   19      0
# Leicester City             9      1      0   27      0      9   0    6      1
# Liverpool FC               6      0      0   51      0      1   1    4      1
# Manchester City           11      0      0   28      0     20   0   21      0
# Manchester United          6      0      0   36      0      1   0   23      0
# Newcastle United           6      0      2   13      0      8   0   11      0
# Sheffield United           3      0      0    6      0      8   0    1      1
# Southampton                4      0      0   21      0      1   0   14      0
# Tottenham Hotspur          3      0      0   52      0      5   0    6      0
# West Bromwich Albion       6      0      0    5      0      6   0    4      0
# West Ham United           10      1      0   13      0     14   0   12      0
# Wolverhampton Wanderers    7      0      0   11      0      6   0    6      1
# All                      129      3     11  442      8    124   1  171     14
#
# Position                 MF,FW  All
# Club
# Arsenal                      2   53
# Aston Villa                  0   52
# Brighton                     2   39
# Burnley                      0   32
# Chelsea                     10   56
# Crystal Palace               1   39
# Everton                      1   45
# Fulham                       2   26
# Leeds United                11   60
# Leicester City              11   64
# Liverpool FC                 1   65
# Manchester City              2   82
# Manchester United            4   70
# Newcastle United             4   44
# Sheffield United             0   19
# Southampton                  7   47
# Tottenham Hotspur            0   66
# West Bromwich Albion        12   33
# West Ham United             10   60
# Wolverhampton Wanderers      3   34
# All                         83  986

# %%
sns.distplot(df.Age)
plt.show()

# %%
sns.lmplot(x='Penalty_Attempted', y='Penalty_Goals', data=df)
plt.show()
